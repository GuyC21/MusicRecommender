# %% [markdown]
# # Summerization

# %% [markdown]
# in the jupyter file, we will take care of this things:

# %% [markdown]
# 1. Loading the SQLink tables into dataframes
# 2. Removing duplicated data
# 3. Creating the merged data that will be the fundemental data for our project
# 4. Pickling the created merged DataFrame so we can easily use it in the actual code

# %%
import sqlite3 #pip install sqlite
import pandas as pd #pip install pandas
import pickle #pip install pickle

# %% [markdown]
# # 1 - Loading the SQLite tables into DataFrames

# %% [markdown]
# Run it all to create a pickle file. After you run it for the first time, no need to do ti again

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
albums = pd.read_sql_query("SELECT * FROM albums", cnx)
albums.head()
# Out:
#                        id                                               name  \
# 0  2jKoVlU7VAmExKJ1Jh3w9P         Alkaholik (feat. Erik Sermon, J Ro & Tash)
# 1  4JYUDRtPZuVNi7FAnbHyux  Flava in Ya Ear Remix (feat. Notorious B.I.G.,...
# 2  6YjKAkDYmlasMqYw73iB0w                                    Bitch Please II
# 3  2YlvHjDb4Tyxl4A1IcDhAe                                       Just Dippin'
# 4  3UOuBNEin5peSRqdzvlnWM                                       Still D.R.E.
#
#   album_group   album_type   release_date  popularity
# 0                    album   954633600000           0
# 1                   single   757382400000           0
# 2                    album   959040000000           0
# 3              compilation  1104537600000           0
# 4                    album   942710400000           0

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
rAlbumsArtists = pd.read_sql_query("SELECT * FROM r_albums_artists", cnx)
rAlbumsArtists.head()
# Out:
#                  album_id               artist_id
# 0  6os2Mv58OYnQClPf7B9E1s  2HS2wQTJXpA65XWOKlAVxk
# 1  5XXN1tFQg7D7U1NSVh5fjf  3VBpsrUi2vV7Uj87ONHu7Z
# 2  63wFVCPZxdaFL9WKXbIQ5m  1kC8lmaSblf7GyK915496r
# 3  0z7p1tHVJ6s5wxAdj9iJ6e  2bTFaANevDESpT5eGWsZ7a
# 4  4afYJvrsp90d3V2COlLHVE  2maQMqxNnlRrBrS1oAsrX9

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode("utf-8",errors = 'ignore')
artists = pd.read_sql_query("SELECT * FROM artists", cnx)
artists.head()
# Out:
#            name                      id  popularity  followers
# 0        Xzibit  4tujQJicOnuZRLiBFdp3Ou          69    1193665
# 1  Erick Sermon  2VX0o9LDIVmKIgpnwdJpOJ          54     142007
# 2         J. Ro  3iBOsmwGzRKyR0vs2I61xP          45        158
# 3          Tash  22qf8cJRzBjIWb2Jc4JeOr          48       3421
# 4    Craig Mack  4akj4uteQQrrGxhX9Rjuyf          55     161966

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
audioFeatures = pd.read_sql_query("SELECT * FROM audio_features", cnx)
audioFeatures.head()

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
genres = pd.read_sql_query("SELECT * FROM genres", cnx)
genres.head()
# Out:
#                  id
# 0   detroit hip hop
# 1            g funk
# 2      gangster rap
# 3  hardcore hip hop
# 4           hip hop

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
rAlbumsTracks = pd.read_sql_query("SELECT * FROM r_albums_tracks", cnx)
rAlbumsTracks.head()
# Out:
#                  album_id                track_id
# 0  6os2Mv58OYnQClPf7B9E1s  3HnrHGLE9u2MjHtdobfWl9
# 1  6os2Mv58OYnQClPf7B9E1s  4lDjkpUrpWlMFofIpzuExK
# 2  6os2Mv58OYnQClPf7B9E1s  4RDT3ftT3V0IJVmW0TNgof
# 3  6os2Mv58OYnQClPf7B9E1s  1DfwOz5apF0w2d8hccSkhH
# 4  6os2Mv58OYnQClPf7B9E1s  46JY9OYPi4hJ7oLIS0FZt0

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
rArtistGenre = pd.read_sql_query("SELECT * FROM r_artist_genre", cnx)
rArtistGenre.head()
# Out:
#            genre_id               artist_id
# 0   detroit hip hop  4tujQJicOnuZRLiBFdp3Ou
# 1            g funk  4tujQJicOnuZRLiBFdp3Ou
# 2      gangster rap  4tujQJicOnuZRLiBFdp3Ou
# 3  hardcore hip hop  4tujQJicOnuZRLiBFdp3Ou
# 4           hip hop  4tujQJicOnuZRLiBFdp3Ou

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
rTrackArtist = pd.read_sql_query("SELECT * FROM r_track_artist", cnx)
rTrackArtist
# Out:
#                         track_id               artist_id
# 0         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 1         2jKoVlU7VAmExKJ1Jh3w9P  2VX0o9LDIVmKIgpnwdJpOJ
# 2         2jKoVlU7VAmExKJ1Jh3w9P  3iBOsmwGzRKyR0vs2I61xP
# 3         2jKoVlU7VAmExKJ1Jh3w9P  22qf8cJRzBjIWb2Jc4JeOr
# 4         4JYUDRtPZuVNi7FAnbHyux  4akj4uteQQrrGxhX9Rjuyf
# ...                          ...                     ...
# 11840397  6ClotRUApTN25L3OnkzQjb  3y9hQYlwNKqhdybIJTFzTr
# 11840398  7mZL8mtlavFzAzIlIfOMv2  5e8vdggiGg9glSpuBgcaiv
# 11840399  7mZL8mtlavFzAzIlIfOMv2  6NgwMiz1Dwsktnn8p8yujE
# 11840400  08ITn8qaxbnEyk3N08IC47  4NEA8zkFgdVHYWZXANEHA7
# 11840401  5Vqgrz2M1m49PRh2eR9et7  4LOzEceyTOhRzbpebCciHR
#
# [11840402 rows x 2 columns]

# %%
cnx = sqlite3.connect('spotify.sqlite')
cnx.text_factory = lambda x: x.decode(encoding='utf-8',errors = 'ignore')
tracks = pd.read_sql_query("SELECT * FROM tracks", cnx)
tracks.head()
# Out:
#                        id  disc_number  duration  explicit  \
# 0  1dizvxctg9dHEyaYTFufVi            1    275893         1
# 1  2g8HN35AnVGIk7B8yMucww            1    252746         1
# 2  49pnyECzcMGCKAqxfTB4JZ            3    315080         0
# 3  4E5IFAXCob6QqZaJMTw5YN            1    240800         1
# 4  1gSt2UlC7mtRtJIc5zqKWn            2    203666         0
#
#          audio_feature_id                                               name  \
# 0  1dizvxctg9dHEyaYTFufVi              Gz And Hustlas (feat. Nancy Fletcher)
# 1  2g8HN35AnVGIk7B8yMucww                          Big Poppa - 2005 Remaster
# 2  49pnyECzcMGCKAqxfTB4JZ  You Were Born - Early Version Of "One Of The T...
# 3  4E5IFAXCob6QqZaJMTw5YN                                Poppin' Them Thangs
# 4  1gSt2UlC7mtRtJIc5zqKWn              It's Hard To Say "I Do", When I Don't
#
#                                          preview_url  track_number  \
# 0                                                               12
# ...

# %% [markdown]
# # 2 - Removing duplicated albums for each artist_id

# %%
albums = albums.sort_values(by='popularity',ascending=False)

# %%
#Merging the two relevent DataFrames in order to be able to get rid of the duplicated albums
albums_merge_artists = pd.merge(rAlbumsArtists,albums,left_on='album_id',right_on='id')
albums_merge_artists.drop(['id'],1,inplace=True)
albums_merge_artists.sort_values(by='popularity',ascending=False,inplace=True)
albums_merge_artists.rename(columns={'name':'albumName'},inplace=True)
albums_merge_artists.drop_duplicates(subset=['albumName','artist_id'],inplace=True)
# Out:
# C:\Users\email_7542vwv\AppData\Local\Temp\ipykernel_16756\898559495.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   albums_merge_artists.drop(['id'],1,inplace=True)

# %% [markdown]
# # 3 - Creating the merged data that will be the fundemental data for our project

# %%
MergedData = pd.merge(rAlbumsTracks,albums_merge_artists[albums_merge_artists['album_type']!='single'])
MergedData = pd.merge(MergedData,audioFeatures,left_on='track_id',right_on='id')
MergedData = MergedData.drop(['id'],1)
MergedData = pd.merge(MergedData,artists[['name','id']],left_on='artist_id',right_on='id')
MergedData = MergedData.drop(['id'],1)
MergedData = MergedData.rename(columns={'name':'artistName'})
MergedData = MergedData.sort_values(by=['popularity'],ascending=False)
# Out:
# C:\Users\email_7542vwv\AppData\Local\Temp\ipykernel_16756\1178831878.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   MergedData = MergedData.drop(['id'],1)
# C:\Users\email_7542vwv\AppData\Local\Temp\ipykernel_16756\1178831878.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   MergedData = MergedData.drop(['id'],1)

# %%
MergedData
# Out:
#                        album_id                track_id  \
# 2103779  5dGWwsZ9iB2Xc3UKR0gif2  6I3mqTwhRpn34SLVafSH7G
# 2103774  5dGWwsZ9iB2Xc3UKR0gif2  137mSruegm1u6x9NvwiagR
# 2103772  5dGWwsZ9iB2Xc3UKR0gif2  3T03rPwlL8NVk1yIaxeD8U
# 2103771  5dGWwsZ9iB2Xc3UKR0gif2  6F2r4HgpJnvKDmkN6JEN6J
# 2103770  5dGWwsZ9iB2Xc3UKR0gif2  5NU40QTlXrDUJzDBdv79bg
# ...                         ...                     ...
# 4610626  76cmayuIiFOm2K3mXzepUh  3Yb3cbIJHiDCdpdJY8Xodu
# 4610627  76cmayuIiFOm2K3mXzepUh  2WHKk1PKUcKVIjbGEwk4D4
# 4610628  76cmayuIiFOm2K3mXzepUh  7zMVQG9UpRwJpfQblfqCk0
# 4610629  76cmayuIiFOm2K3mXzepUh  5UDW4e763ymOW9ELQ4fwR7
# 9183745  6oWHg6D147MZOGy2smMNpI  2Zikl6KD7XMLQ16N25UCZA
#
#                       artist_id  \
# 2103779  1uNFoZAHBGtllmzznpCI3s
# 2103774  1uNFoZAHBGtllmzznpCI3s
# 2103772  1uNFoZAHBGtllmzznpCI3s
# 2103771  1uNFoZAHBGtllmzznpCI3s
# 2103770  1uNFoZAHBGtllmzznpCI3s
# ...                         ...
# 4610626  3AnH1n9G6Y9TyoPqGNo3Ig
# ...

# %% [markdown]
# # 4 - Pickling the data

# %%
#this was running localy to create the MergedData pickle file. you dont need to run it

def storeData(df):
    dbfile = open('MergedData','ab')
    pickle.dump(df, dbfile)
    dbfile.close()

storeData(MergedData)
# Out:
# "def storeData(df):\n    dbfile = open('MergedData','ab')\n    pickle.dump(df, dbfile)\n    dbfile.close()\n\nstoreData(MergedData)"
